# %%
'''
this file was used to inspect which taxa were only in flowcam or microscopy
to figure out if there may have been naming errors or trends in which taxa were exclusive to each.
'''
import glob
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
flow_df = pd.read_excel('./FinnisData-20241007T133632Z-001/FinnisData/Method Paper/flowcamDataMethodPaper_RawCounts.xlsx')
mic_df = pd.read_excel('./FinnisData-20241007T133632Z-001/FinnisData/Method Paper/microscopyDataMethodPaper_RawCounts.xlsx')

# %%
flowname_df = pd.read_excel('./FinnisData-20241007T133632Z-001/FinnisData/Method Paper/methodPaperZooNameChanges.xlsx', sheet_name='flowcamAdjustments')

# %%
for i, row in flowname_df.iterrows():
    flow_df.replace({row['flowcamName']: row['newName']})
flow_df['originalNames'].unique()
# Out:
# array(['Acartia spp Civ-vi', 'Centropages spp Civ-vi',
#        'Unidentified Copepoda', 'Eurytemora spp Civ-vi',
#        'Evadne spp Civ-vi', 'Harpacticoida Ci-vi',
#        'Hydrozoa juvenile medusa', 'Obelia spp medusa',
#        'Oithona spp Civ-vi', 'Podon/Pleopis spp',
#        'Pseudocalanus spp Civ-vi ', 'Temora spp Civ-vi',
#        'Unidentified Zooplankton', 'Aglantha digitale medusa',
#        'Amphipoda', 'Bivalvia larvae', 'Calanus spp',
#        'Gastropoda larvae/Lamacina spp', 'Metridia spp Civ-vi',
#        'Oikopleura spp', 'Echinodermata larvae', 'Chaetognatha',
#        'Chiridus spp Civ-vi', 'Unidentified copepoda', 'Fritillaria spp',
#        'Invertebrate trochophore larvae', 'Unidentified zooplankton',
#        'Anthoathecata medusa', 'Unidentified Calanoida',
#        'Cnidaria actinula larvae', 'Hydrozoa Juvenile medusa',
#        'Invertebrate trochophore/larvae', 'Osteichthys eggs',
#        'Tomopteris spp juvenile', 'Caridea zoea larvae/Paragus spp zoea',
#        'Cnidaria actinula Larvae', 'Polychaeta larvae',
#        'Acartia_spp_Civ-vi', 'Aglantha_spp_medusa', 'Bivalvia_larvae',
#        'Bryozoa_larvae', 'Calanoida_Ci-iii', 'Calanoida_Civ-vi',
#        'Calanus_spp_Civ-vi', 'Centropages_spp_Civ-vi',
#        'Echinodermata_larvae', 'Eurytemora_spp_Civ-vi', 'Evadne_spp',
#        'Gastropoda_Limacina_spp_larvaeAdult', 'Harpacticoida_Civ-vi',
#        'Hydrozoa_juvenile_medusa', 'Microcalanus_spp_Civ-vi',
#        'Oikopleura_spp', 'Oithona_spp_Civ-vi', 'Podon_Pleopis_spp',
#        'Polychaeta_larvae', 'Pseudocalanus_spp_Civ-vi',
#        'Temoridae_spp_Civ-vi', 'Tortanus_spp_Civ-vi', 'Unid_Zooplankton',
#        'Chaetognatha (juvenile or n.s.)', 'Fritillaria_spp',
#        'Invertebrate_trochophore', 'Oncaeidae_Civ-vi',
#        'Calanus_spp_Ci-iii', 'Ostracoda', 'Sarsia_spp_medusa',
#        'Temora_spp_Civ-vi', 'Osteichthyes_eggs',
#        'Decapoda_NonBrachyura_zoea', 'Cyclopoida_Ci-iii', 'Foraminifera',
#        'Monstrillidae_spp', 'Calanoida (Unid)', 'Copepoda_nauplii',
#        'Cyclopoida_Ci-vi', 'Decapoda_NonBrachyura_zoea_larvae',
#        'Gastropoda_Limacina_spp', 'Harpacticoida_Ci-vi',
#        'Hydrozoa_medusa', 'Obelia_spp_medusa',
#        'Pseudodiaptomus_spp_Civ-vi', 'Zooplankton (Unid)',
#        'Cirripedia_cypris_nauplii', 'Calananoida (Unid)',
#        'Chaetognatha_juvenile', 'Cnidaria_actinula_larvae',
#        'Monstrilloida', 'Paracalanus_spp', 'Ascidiacea_larvae',
#        'Cyclopoida', 'Microsetella_spp_Ci-vi',
#        'Decapoda_Brachyura_zoea_larvae', 'Osteichthys_larvae',
#        'Calycophorae_nectophore', 'Centropages_Civ-vi',
#        'Cirripedia_cypris', 'Cirripedia_nauplius', 'Corycaeidae_Civ-vi',
#        'Ctenophora_larvae', 'Decapoda_Brachyura_zoea',
#        'Euphysa_spp_medusa', 'Gastropoda_larvae',
#        'Invertebrate_egg_trochophore', 'Paracalanus_spp_Civ-vi',
#        'Osteichthys_eggs', 'Porcellanidae_zoea', 'Pseudocalanus_spp',
#        'Cyclopoida_spp', 'Corycaeidae_Ci-iii', 'Actinopterygii_larva',
#        'Centropages_Ci-vi', 'Osteichthys_egg', 'Ostracoda_spp'],
#       dtype=object)

# %%
taxa_exclusion_list = [
    'Ctenophora (juvenile/adult)',
    'Scyphozoa (larvae)',
    'Isopoda (larvae)',
    'Neoturris spp. (medusa)',
    'Platyhelminthes/Nemertea (juvenile)',
    'Platyhelminthes/Nemertea (larvae)',
    'Siphonophorae (nectophore)',
    'Sarsia spp. (medusa)',
    'Amphipoda- epibenthic',
    'Leuckartiara spp. (medusa)',
    'Alciopidae sp.',
    'Epilabidocera spp.',
    'Scyphozoa (medusa)',
]
flow_df = flow_df[~flow_df['originalNames'].isin(taxa_exclusion_list)]
mic_df = mic_df[~mic_df['newName'].isin(taxa_exclusion_list)]

# %%
flow_names = flow_df['originalNames'].unique()
mic_names = mic_df['newName'].unique()
print(len(mic_names))
mic_names
# Out:
# 36
# array(['Podon/Pleopsis spp.', 'Chaetognatha', 'Oikopleura spp.',
#        'Hydrozoa (medusa)', 'Echinodermata (larvae)', 'Bivalvia (larvae)',
#        'Aglantha spp. (medusa)', 'Bryozoa (larvae)',
#        'Calanoida (ci-ciii)', 'Pseudocalanus spp.', 'Acartia spp.',
#        'Oithona spp.', 'Temora spp.', 'Centropages spp.',
#        'Eurytemora spp.', 'Tortanus spp.', 'Harpacticoida- epibenthic',
#        'Gastropoda (larvae/Limacina)', 'Polychaeta (larvae)',
#        'Fritillaria spp.', 'Invertebrate (egg, trochophore larvae)',
#        'Calanus spp.', 'Obelia spp. (medusa)', 'Microcalanus spp.',
#        'Copepoda (nauplii)', 'Pseudodiaptomus spp.',
#        'Ascidiacea (larvae)', 'Cirripedia (larvae)', 'Paracalanus spp.',
#        'Corycaeidae', 'Egg mass: REMOVE', 'Decapoda- brachyura (larvae)',
#        'Decapoda: Distribute abundances between non-brachyura and brachyura',
#        'Decapoda- non-brachyura (larvae)', 'Osteichthyes (larvae)',
#        'Calycophorae (nectophore)'], dtype=object)

# %%
len(mic_df['newName'])
# Out:
# 778

# %%
set1 = set(new_flow_names)
set2 = set(mic_names)

# Values in list1 that are not in list2
only_in_list1 = set1 - set2

# Values in list2 that are not in list1
only_in_list2 = set2 - set1

print("Values in new_flow_names but not in mic_names:", only_in_list1)
print("Values in mic_names but not in new_flow_names:", only_in_list2)
# Out:
# Values in new_flow_names but not in mic_names: {'Sarsia_spp_medusa', 'Cyclopoida (unid)', 'Metridia spp.', 'Foraminifera', 'Euphysa spp. (medusa)', 'Amphipoda', 'Osteichthyes_eggs', 'Chaetognatha (juvenile or n.s.)', 'Ostracoda', 'Copepoda (unid)', 'Tomopteris spp.', 'Chiridius spp.', 'Cnidaria (larvae)', 'Osteichthyes egg', 'Oncaeidae_Civ-vi', 'Anthoathecata (medusa)', 'Monstrillidae', 'Ctenophora larvae', 'Calanoida (unid)', 'Zooplankton (unid)', 'Evadne spp.', 'Microsetella spp.'}
# Values in mic_names but not in new_flow_names: {'Egg mass: REMOVE', 'Decapoda: Distribute abundances between non-brachyura and brachyura'}

# %%
print("-------------------only in microscopy: ")
microscopy_list = []
for item in only_in_list2:
    if 'Egg' not in item and 'Decapoda' not in item:
        print(item)
        microscopy_list.append(item)
# Out:
# -------------------only in microscopy:

# %%
name_count_dict = {
'Alciopidae sp.': 1,
 'Amphipoda- epibenthic': 1,
 'Ctenophora (juvenile/adult)': 10,
 'Epilabidocera spp.': 1,
 'Isopoda (larvae)': 1,
 'Leuckartiara spp. (medusa)': 2,
 'Neoturris spp. (medusa)': 2,
 'Platyhelminthes/Nemertea (juvenile)': 1,
 'Platyhelminthes/Nemertea (larvae)': 1,
 'Sarsia spp. (medusa)': 4,
 'Scyphozoa (larvae)': 1,
 'Scyphozoa (medusa)': 2,
 'Siphonophorae (nectophore)': 10
}

# %%
print("-------------------only in flowcam: ")
for item in only_in_list1:
    if 'unid' not in item:
        print(item)
# Out:
# -------------------only in flowcam:
# Sarsia_spp_medusa
# Metridia spp.
# Foraminifera
# Euphysa spp. (medusa)
# Amphipoda
# Osteichthyes_eggs
# Chaetognatha (juvenile or n.s.)
# Ostracoda
# Tomopteris spp.
# Chiridius spp.
# Cnidaria (larvae)
# Osteichthyes egg
# Oncaeidae_Civ-vi
# Anthoathecata (medusa)
# Monstrillidae
# Ctenophora larvae
# Evadne spp.
# Microsetella spp.

# %%
flow_df[flow_df['originalNames'] == 'Sarsia_spp_medusa']
# Out:
#                        sampleCode              flowcamFileName  \
# 266  21_10_05_NL_S01_Z41_0854_250  21_10_05_NL_S1_Z41_0854_250
# 319  21_10_06_NL_S01_Z17_0802_250  21_10_06_NL_S1_Z17_0802_250
#
#                     qaSampleID  yearStart  monthStart  dayStart  \
# 266  21-10-5-NL-S1-Z41-854-250       2021          10         5
# 319  21-10-6-NL-S1-Z17-802-250       2021          10         6
#
#       facilityName        region  depthWaterM  waterVolume  ... equipmentType  \
# 266  Southeast Arm  Newfoundland         45.0     8.835722  ...    250 um net
# 319  Southeast Arm  Newfoundland         44.0     8.639373  ...    250 um net
#
#       TowType netMesh      originalNames count            dataset  \
# 266  vertical     250  Sarsia_spp_medusa     2  Newfoundland 2021
# 319  vertical     250  Sarsia_spp_medusa     2  Newfoundland 2021
#
#     fracSampleCleaned  fracZooIdentified finnisMapLabel    tidePhase
# 266               1.0           0.752926          Mid-B  Mid-Falling
# 319               1.0           0.600000          Outer         High
#
# [2 rows x 23 columns]

# %%
flow_df
# Out:
#                           sampleCode                  flowcamFileName  \
# 0       20_09_15_NL_S01_Z77_1451_250  AMMP_NL_S01_77_20200915PM_250UM
# 1       20_09_15_NL_S01_Z77_1451_250  AMMP_NL_S01_77_20200915PM_250UM
# 2       20_09_15_NL_S01_Z77_1451_250  AMMP_NL_S01_77_20200915PM_250UM
# 3       20_09_15_NL_S01_Z77_1451_250  AMMP_NL_S01_77_20200915PM_250UM
# 4       20_09_15_NL_S01_Z77_1451_250  AMMP_NL_S01_77_20200915PM_250UM
# ..                               ...                              ...
# 953  AMMP_PA_S04W01_20210610HT_250um    AMMP_PA_S04W01_20210610HT_5mm
# 954  AMMP_PA_S04W01_20210610HT_250um    AMMP_PA_S04W01_20210610HT_5mm
# 955  AMMP_PA_S04W01_20210610HT_250um    AMMP_PA_S04W01_20210610HT_5mm
# 956  AMMP_PA_S04W01_20210610HT_250um    AMMP_PA_S04W01_20210610HT_5mm
# 957  AMMP_PA_S04W01_20210610HT_250um    AMMP_PA_S04W01_20210610HT_5mm
#
#                                     qaSampleID  yearStart  monthStart  \
# 0           AMMP_NL_S01_77_2020.09.15_PM_250um       2020           9
# 1           AMMP_NL_S01_77_2020.09.15_PM_250um       2020           9
# 2           AMMP_NL_S01_77_2020.09.15_PM_250um       2020           9
# 3           AMMP_NL_S01_77_2020.09.15_PM_250um       2020           9
# 4           AMMP_NL_S01_77_2020.09.15_PM_250um       2020           9
# ..                                         ...        ...         ...
# 953  AMMP_Pacific_S04W01_250um_High_2021-06-10       2021           6
# 954  AMMP_Pacific_S04W01_250um_High_2021-06-10       2021           6
# 955  AMMP_Pacific_S04W01_250um_High_2021-06-10       2021           6
# 956  AMMP_Pacific_S04W01_250um_High_2021-06-10       2021           6
# 957  AMMP_Pacific_S04W01_250um_High_2021-06-10       2021           6
#
#      dayStart   facilityName        region  depthWaterM  waterVolume  ...  \
# 0          15  Southeast Arm  Newfoundland         17.0     3.100000  ...
# 1          15  Southeast Arm  Newfoundland         17.0     3.100000  ...
# 2          15  Southeast Arm  Newfoundland         17.0     3.100000  ...
# 3          15  Southeast Arm  Newfoundland         17.0     3.100000  ...
# 4          15  Southeast Arm  Newfoundland         17.0     3.100000  ...
# ..        ...            ...           ...          ...          ...  ...
# 953        10        LEMMENS       Pacific         16.0    17.116973  ...
# 954        10        LEMMENS       Pacific         16.0    17.116973  ...
# 955        10        LEMMENS       Pacific         16.0    17.116973  ...
# 956        10        LEMMENS       Pacific         16.0    17.116973  ...
# 957        10        LEMMENS       Pacific         16.0    17.116973  ...
#
#        equipmentType   TowType netMesh               originalNames count  \
# 0          250um net  Vertical     250          Acartia spp Civ-vi   787
# 1          250um net  Vertical     250      Centropages spp Civ-vi    28
# 2          250um net  Vertical     250       Unidentified Copepoda    85
# 3          250um net  Vertical     250       Eurytemora spp Civ-vi    27
# 4          250um net  Vertical     250           Evadne spp Civ-vi   175
# ..               ...       ...     ...                         ...   ...
# 953  50 x 150 cm Net  Vertical     250  Decapoda_NonBrachyura_zoea     3
# 954  50 x 150 cm Net  Vertical     250             Hydrozoa_medusa     2
# 955  50 x 150 cm Net  Vertical     250              Oikopleura_spp    17
# 956  50 x 150 cm Net  Vertical     250           Polychaeta_larvae     2
# 957  50 x 150 cm Net  Vertical     250         Tortanus_spp_Civ-vi    12
#
#                dataset fracSampleCleaned  fracZooIdentified finnisMapLabel  \
# 0    Newfoundland 2020               1.0                1.0          Inner
# 1    Newfoundland 2020               1.0                1.0          Inner
# 2    Newfoundland 2020               1.0                1.0          Inner
# 3    Newfoundland 2020               1.0                1.0          Inner
# 4    Newfoundland 2020               1.0                1.0          Inner
# ..                 ...               ...                ...            ...
# 953  Pacific June 2021               1.0                1.0          Outer
# 954  Pacific June 2021               1.0                1.0          Outer
# 955  Pacific June 2021               1.0                1.0          Outer
# 956  Pacific June 2021               1.0                1.0          Outer
# 957  Pacific June 2021               1.0                1.0          Outer
#
#       tidePhase
# 0    Mid-Rising
# 1    Mid-Rising
# 2    Mid-Rising
# 3    Mid-Rising
# 4    Mid-Rising
# ..          ...
# 953        High
# 954        High
# 955        High
# 956        High
# 957        High
#
# [958 rows x 23 columns]

# %%
for name in microscopy_list:
    print('----------', name, '---------------')
    name_df = mic_df[mic_df['newName'] == name]
    samples = name_df['FlowCamID'].unique()
    sampleCount = len(samples)
    for sample in samples:
        print(f"sample: {sample}, {name_df[name_df['FlowCamID'] == sample]['countSample'].sum()}")
# Out:
# ---------- Ctenophora (juvenile/adult) ---------------
# sample: AMMP_PA_S04W01_20210609LT_250um, 4
# sample: AMMP_PA_S04W15_20210609LT_250um, 1
# sample: AMMP_PA_S04W20_20210609LT_250um, 2
# sample: AMMP_PA_S04W01_20210609HT_250um, 13
# sample: AMMP_PA_S04W15_20210609HT_250um, 6
# sample: AMMP_PA_S04W20_20210609HT_250um, 1
# sample: AMMP_PA_S04W20_20210610LT_250um, 8
# sample: AMMP_PA_S04W15_20210610LT_250um, 2
# sample: AMMP_PA_S04W01_20210610LT_250um, 11
# sample: AMMP_PA_S04W01_20210610HT_250um, 5
# ---------- Scyphozoa (larvae) ---------------
# sample: AMMP_PA_S04W20_20210609LT_250um, 1
# ---------- Isopoda (larvae) ---------------
# sample: AMMP_PA_S04W20_20210609HT_250um, 1
# ---------- Neoturris spp. (medusa) ---------------
# sample: AMMP_PA_S04W20_20210609HT_250um, 1
# sample: AMMP_PA_S04W20_20210610LT_250um, 1
# ---------- Platyhelminthes/Nemertea (juvenile) ---------------
# sample: AMMP_PA_S04W01_20210609LT_250um, 1
# ---------- Platyhelminthes/Nemertea (larvae) ---------------
# sample: AMMP_PA_S04W15_20210610LT_250um, 1
# ---------- Siphonophorae (nectophore) ---------------
# sample: AMMP_PA_S04W01_20210609LT_250um, 6
# sample: AMMP_PA_S04W15_20210609LT_250um, 5
# sample: AMMP_PA_S04W20_20210609LT_250um, 8
# sample: AMMP_PA_S04W01_20210609HT_250um, 7
# sample: AMMP_PA_S04W15_20210609HT_250um, 4
# sample: AMMP_PA_S04W20_20210609HT_250um, 11
# sample: AMMP_PA_S04W20_20210610LT_250um, 5
# sample: AMMP_PA_S04W15_20210610LT_250um, 4
# sample: AMMP_PA_S04W01_20210610LT_250um, 9
# sample: AMMP_PA_S04W01_20210610HT_250um, 4
# ---------- Sarsia spp. (medusa) ---------------
# sample: 21_10_05_NL_S1_Z17_1406_250, 1
# sample: AMMP_PA_S04W20_20210609LT_250um, 1
# sample: AMMP_PA_S04W15_20210609HT_250um, 1
# sample: AMMP_PA_S04W20_20210610LT_250um, 1
# ---------- Amphipoda- epibenthic ---------------
# sample: AMMP_PA_S04W15_20210610LT_250um, 1
# ---------- Leuckartiara spp. (medusa) ---------------
# sample: AMMP_PA_S04W15_20210609LT_250um, 2
# sample: AMMP_PA_S04W15_20210610LT_250um, 1
# ---------- Alciopidae sp. ---------------
# sample: AMMP_PA_S04W20_20210609LT_250um, 1
# ---------- Epilabidocera spp. ---------------
# sample: AMMP_PA_S04W20_20210610LT_250um, 1
# ---------- Scyphozoa (medusa) ---------------
# sample: AMMP_PA_S04W20_20210609LT_250um, 2
# sample: AMMP_PA_S04W15_20210610LT_250um, 4

# %%
pac_mic_df = mic_df[mic_df['regionYear'] == 'Pac 21']

# %%
pac_mic_df.groupby('newName')['countSample'].sum()
# Out:
# newName
# Acartia spp.                                                           1459
# Alciopidae sp.                                                            1
# Amphipoda- epibenthic                                                     1
# Ascidiacea (larvae)                                                       4
# Bivalvia (larvae)                                                       154
# Bryozoa (larvae)                                                          1
# Calanoida (ci-ciii)                                                      57
# Calycophorae (nectophore)                                                 3
# Centropages spp.                                                         61
# Chaetognatha                                                              3
# Cirripedia (larvae)                                                     660
# Copepoda (nauplii)                                                        8
# Corycaeidae                                                             220
# Ctenophora (juvenile/adult)                                              53
# Decapoda- brachyura (larvae)                                            144
# Decapoda- non-brachyura (larvae)                                         57
# Decapoda: Distribute abundances between non-brachyura and brachyura      27
# Echinodermata (larvae)                                                   29
# Egg mass: REMOVE                                                       1296
# Epilabidocera spp.                                                        1
# Evadne spp.                                                             143
# Fritillaria spp.                                                        218
# Gastropoda (larvae/Limacina)                                            142
# Harpacticoida- epibenthic                                                 2
# Hydrozoa (medusa)                                                        55
# Isopoda (larvae)                                                          1
# Leuckartiara spp. (medusa)                                                3
# Neoturris spp. (medusa)                                                   2
# Obelia spp. (medusa)                                                      4
# Oikopleura spp.                                                         661
# Oithona spp.                                                             14
# Osteichthyes (larvae)                                                     3
# Paracalanus spp.                                                        157
# Platyhelminthes/Nemertea (juvenile)                                       1
# Platyhelminthes/Nemertea (larvae)                                         1
# Podon/Pleopsis spp.                                                     335
# Polychaeta (larvae)                                                      46
# Pseudocalanus spp.                                                       27
# Sarsia spp. (medusa)                                                      3
# Scyphozoa (larvae)                                                        1
# Scyphozoa (medusa)                                                        6
# Siphonophorae (nectophore)                                               63
# Tortanus spp.                                                            29
# Name: countSample, dtype: int64

# %%
pac_mic_names
# Out:
# array(['Hydrozoa (medusa)', 'Cirripedia (larvae)', 'Evadne spp.',
#        'Podon/Pleopsis spp.', 'Acartia spp.', 'Calanoida (ci-ciii)',
#        'Pseudocalanus spp.', 'Paracalanus spp.', 'Copepoda (nauplii)',
#        'Corycaeidae', 'Oithona spp.', 'Harpacticoida- epibenthic',
#        'Ctenophora (juvenile/adult)', 'Echinodermata (larvae)',
#        'Bivalvia (larvae)', 'Egg mass: REMOVE',
#        'Gastropoda (larvae/Limacina)',
#        'Platyhelminthes/Nemertea (juvenile)', 'Polychaeta (larvae)',
#        'Fritillaria spp.', 'Oikopleura spp.',
#        'Siphonophorae (nectophore)', 'Centropages spp.', 'Tortanus spp.',
#        'Decapoda- brachyura (larvae)',
#        'Decapoda: Distribute abundances between non-brachyura and brachyura',
#        'Decapoda- non-brachyura (larvae)', 'Bryozoa (larvae)',
#        'Obelia spp. (medusa)', 'Ascidiacea (larvae)', 'Chaetognatha',
#        'Leuckartiara spp. (medusa)', 'Sarsia spp. (medusa)',
#        'Scyphozoa (larvae)', 'Scyphozoa (medusa)',
#        'Osteichthyes (larvae)', 'Alciopidae sp.', 'Isopoda (larvae)',
#        'Neoturris spp. (medusa)', 'Epilabidocera spp.',
#        'Platyhelminthes/Nemertea (larvae)', 'Amphipoda- epibenthic',
#        'Calycophorae (nectophore)'], dtype=object)

# %%
gulf_tax_counts = []
flow_samples = flow_df['qaSampleID'].unique()
for sample in flow_samples:
    taxa_list = flow_df[(flow_df['qaSampleID'] == sample) & (flow_df['region'] == 'Gulf')]['originalNames'].unique()
    if len(taxa_list) > 0:
        gulf_tax_counts.append(len(taxa_list))
        print(len(taxa_list))
plt.plot(gulf_tax_counts)
plt.scatter(range(len(gulf_tax_counts)), gulf_tax_counts)
plt.show()
plt.close()
# Out:
# 16
# 11
# 25
# 16
# 12
# 18
# 22
# 29
# 15
# 15
